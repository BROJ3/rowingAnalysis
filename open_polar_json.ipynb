# %% [markdown]
# <a href="https://colab.research.google.com/github/BROJ3/rowingAnalysis/blob/main/open_polar_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
import json

# Specify the path to your JSON file
file_path = '/content/trening.json'

# Open the file and load the JSON data
with open(file_path, 'r') as file:
    data = json.load(file)

# Now 'data' contains the contents of the JSON file as a Python data structure (e.g., dictionary or list)
data
# Out:
# {'exportVersion': '2.0',
#  'name': 'Indoor rowing',
#  'deviceId': '51A85F2A',
#  'note': '15 min zagrijavanje 1: 56,4\r\n3x752   1:55-1:46-1:42\r\n\r\nzapisano na logbook\r\nborg 15',
#  'startTime': '2024-02-03T14:22:08.000',
#  'stopTime': '2024-02-03T15:55:08.000',
#  'timeZoneOffset': -300,
#  'duration': 'PT5572.625S',
#  'maximumHeartRate': 185,
#  'averageHeartRate': 135,
#  'kiloCalories': 1238,
#  'physicalInformationSnapshot': {'dateTime': '2024-02-03T21:34:20.000',
#   'sex': 'MALE',
#   'birthday': '1998-01-26',
#   'height, cm': 182.0,
#   'weight, kg': 78.0,
#   'vo2Max': 68,
#   'maximumHeartRate': 199,
#   'restingHeartRate': 40,
#   'aerobicThreshold': 149,
#   'anaerobicThreshold': 179,
#   'functionalThresholdPower': 345},
#  'exercises': [{'startTime': '2024-02-03T14:22:08.000',
#    'stopTime': '2024-02-03T15:55:00.625',
#    'timezoneOffset': -300,
#    'duration': 'PT5572.625S',
#    'sport': 'INDOOR_ROWING',
#    'kiloCalories': 1238,
# ...

# %%
toplista=[]
for i in data['exercises']:
  toplista.append(i)

# %%
toplista[0]
# Out:
# {'startTime': '2024-02-03T14:22:08.000',
#  'stopTime': '2024-02-03T15:55:00.625',
#  'timezoneOffset': -300,
#  'duration': 'PT5572.625S',
#  'sport': 'INDOOR_ROWING',
#  'kiloCalories': 1238,
#  'heartRate': {'min': 43, 'avg': 135, 'max': 185},
#  'zones': {'heart_rate': [{'lowerLimit': 90,
#     'higherLimit': 146,
#     'inZone': 'PT2010S',
#     'zoneIndex': 1},
#    {'lowerLimit': 146,
#     'higherLimit': 166,
#     'inZone': 'PT1407S',
#     'zoneIndex': 2},
#    {'lowerLimit': 166, 'higherLimit': 176, 'inZone': 'PT480S', 'zoneIndex': 3},
#    {'lowerLimit': 176, 'higherLimit': 182, 'inZone': 'PT596S', 'zoneIndex': 4},
#    {'lowerLimit': 182,
#     'higherLimit': 192,
#     'inZone': 'PT200S',
#     'zoneIndex': 5}]},
#  'laps': [{'lapNumber': 0,
#    'duration': 'PT47.750S',
#    'splitTime': 'PT47.750S',
#    'heartRate': {'min': 43, 'avg': 46, 'max': 61}},
#   {'lapNumber': 1,
#    'duration': 'PT901.875S',
#    'splitTime': 'PT949.625S',
# ...

# %%
# prompt: get all the values in "toplista" list that have "heartRate" property

heart_rate_list = [exercise for exercise in toplista if 'heartRate' in exercise]

# %%
heart_rate_list[2:5]
# Out:
# []

# %%
# prompt: plot everything in data['exercises']

import pandas as pd
df = pd.json_normalize(data['exercises'])
fig = px.line(df, y="heartRate")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-49d261605e85> in <cell line: 5>()
#       3 import pandas as pd
#       4 df = pd.json_normalize(data['exercises'])
# ----> 5 fig = px.line(df, y="heartRate")
#       6 fig.show()
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     262     a polyline mark in 2D space.
# ...

# %%
data['exercises']
# Out:
# [{'startTime': '2024-02-03T14:22:08.000',
#   'stopTime': '2024-02-03T15:55:00.625',
#   'timezoneOffset': -300,
#   'duration': 'PT5572.625S',
#   'sport': 'INDOOR_ROWING',
#   'kiloCalories': 1238,
#   'heartRate': {'min': 43, 'avg': 135, 'max': 185},
#   'zones': {'heart_rate': [{'lowerLimit': 90,
#      'higherLimit': 146,
#      'inZone': 'PT2010S',
#      'zoneIndex': 1},
#     {'lowerLimit': 146,
#      'higherLimit': 166,
#      'inZone': 'PT1407S',
#      'zoneIndex': 2},
#     {'lowerLimit': 166,
#      'higherLimit': 176,
#      'inZone': 'PT480S',
#      'zoneIndex': 3},
#     {'lowerLimit': 176,
#      'higherLimit': 182,
#      'inZone': 'PT596S',
#      'zoneIndex': 4},
#     {'lowerLimit': 182,
#      'higherLimit': 192,
#      'inZone': 'PT200S',
#      'zoneIndex': 5}]},
#   'laps': [{'lapNumber': 0,
#     'duration': 'PT47.750S',
#     'splitTime': 'PT47.750S',
#     'heartRate': {'min': 43, 'avg': 46, 'max': 61}},
#    {'lapNumber': 1,
# ...
